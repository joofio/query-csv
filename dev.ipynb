# %%
import pandas as pd

# %%
data=pd.read_csv("data/merged_file_v4.xlsx - STEP 1 - Complete Database.csv")

# %%
data=data[["Institution_Name","Institution_School","Course_Name", 'Course_Level(ii)']]

# %%
data.columns
# Out:
# Index(['Institution_Name', 'Institution_School', 'Course_Name',
#        'Course_Level(ii)'],
#       dtype='object')

# %%
data
# Out:
#                                        Institution_Name  \
# 0                                 Universidade de Évora
# 1                                 Universidade de Évora
# 2                                 Universidade de Évora
# 3                                 Universidade do Porto
# 4                                 Universidade do Porto
# ...                                                 ...
# 4310                       Universidade Fernando Pessoa
# 4311                       Universidade Fernando Pessoa
# 4312  Escola Superior de Saúde da Fundação 'Fernando...
# 4313                     Instituto Politécnico do Porto
# 4314   Escola Superior de Tecnologias e Artes de Lisboa
#
#                                   Institution_School  \
# 0                    Escola de Ciências e Tecnologia
# 1                                                NaN
# 2                                                NaN
# 3      Instituto de Ciências Biomédicas Abel Salazar
# 4      Instituto de Ciências Biomédicas Abel Salazar
# ...                                              ...
# 4310                        Escola Superior de Saúde
# 4311                        Escola Superior de Saúde
# 4312                                             NaN
# 4313               Escola Superior de Saúde do Porto
# 4314                                             NaN
#
#                             Course_Name                 Course_Level(ii)
# 0     Acompanhamento Farmacoterapêutico                         Mestrado
# 1     Acompanhamento Farmacoterapêutico                         Mestrado
# 2     Acompanhamento Farmacoterapêutico  Especialização pós-licenciatura
# 3               Aconselhamento Genético           Doutoramento 3.º ciclo
# 4               Aconselhamento Genético               Mestrado 2.º ciclo
# ...                                 ...                              ...
# 4310                Terapêutica da Fala               Mestrado 2.º ciclo
# 4311                Terapêutica da Fala           Licenciatura bietápica
# 4312                Terapêutica da Fala           Licenciatura 1.º ciclo
# 4313                Terapêutica da Fala           Licenciatura bietápica
# 4314      Voz Patológica e Profissional  Especialização pós-licenciatura
#
# [4315 rows x 4 columns]

# %%
data.drop_duplicates(inplace=True)
# Out:
# /var/folders/8g/rym67m5d29dcjm2td47sgb_m0000gn/T/ipykernel_22653/2282015914.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data.drop_duplicates(inplace=True)

# %%
query=ignorecase = re.compile('test', re.IGNORECASE)

# %%
query=r'saúde|ciências|tecnologia|medicina|enfermagem|farmac'

# %%
dataa
# Out:
#                                        Institution_Name  \
# 0                                 Universidade de Évora
# 1                                 Universidade de Évora
# 2                                 Universidade de Évora
# 3                                 Universidade do Porto
# 4                                 Universidade do Porto
# ...                                                 ...
# 4310                       Universidade Fernando Pessoa
# 4311                       Universidade Fernando Pessoa
# 4312  Escola Superior de Saúde da Fundação 'Fernando...
# 4313                     Instituto Politécnico do Porto
# 4314   Escola Superior de Tecnologias e Artes de Lisboa
#
#                                   Institution_School  \
# 0                    Escola de Ciências e Tecnologia
# 1                                                NaN
# 2                                                NaN
# 3      Instituto de Ciências Biomédicas Abel Salazar
# 4      Instituto de Ciências Biomédicas Abel Salazar
# ...                                              ...
# 4310                        Escola Superior de Saúde
# 4311                        Escola Superior de Saúde
# 4312                                             NaN
# 4313               Escola Superior de Saúde do Porto
# 4314                                             NaN
#
#                             Course_Name                 Course_Level(ii)
# 0     Acompanhamento Farmacoterapêutico                         Mestrado
# 1     Acompanhamento Farmacoterapêutico                         Mestrado
# 2     Acompanhamento Farmacoterapêutico  Especialização pós-licenciatura
# 3               Aconselhamento Genético           Doutoramento 3.º ciclo
# 4               Aconselhamento Genético               Mestrado 2.º ciclo
# ...                                 ...                              ...
# 4310                Terapêutica da Fala               Mestrado 2.º ciclo
# 4311                Terapêutica da Fala           Licenciatura bietápica
# 4312                Terapêutica da Fala           Licenciatura 1.º ciclo
# 4313                Terapêutica da Fala           Licenciatura bietápica
# 4314      Voz Patológica e Profissional  Especialização pós-licenciatura
#
# [4067 rows x 4 columns]

# %%
#r'foo(?!$)'
data[data['Course_Name'].str.contains(query)]
# Out:
#                         Institution_Name  \
# 15                 Universidade do Porto
# 25    Instituto Universitário Egas Moniz
# 26      Universidade Católica Portuguesa
# 27      Universidade Católica Portuguesa
# 28               Universidade de Coimbra
# ...                                  ...
# 3706   Instituto Politécnico de Bragança
# 3897               Universidade do Porto
# 3898               Universidade do Porto
# 3899    Universidade Católica Portuguesa
# 3900         Universidade Nova de Lisboa
#
#                                      Institution_School  \
# 15                                Faculdade de Ciências
# 25                                                  NaN
# 26     Escola Superior de Biotecnologia (Caldas da R...
# 27                     Escola Superior de Biotecnologia
# 28                   Faculdade de Ciências e Tecnologia
# ...                                                 ...
# 3706               Escola Superior de Saúde de Bragança
# 3897                              Faculdade de Farmácia
# 3898      Instituto de Ciências Biomédicas Abel Salazar
# 3899                            Faculdade de Engenharia
# 3900           Instituto de Higiene e Medicina Tropical
#
#                                             Course_Name  \
# 15     Aplicações em Biotecnologia e Biologia Sintética
# 25                                          Biociências
# 26                                          Biociências
# 27                                          Biociências
# 28                                          Biociências
# ...                                                 ...
# 3706  Ciências Aplicadas à Saúde ? áreas de especial...
# 3897  Biotecnologia Molecular e Celular Aplicada às ...
# 3898  Biotecnologia Molecular e Celular Aplicada às ...
# 3899                               Biotecnologia Médica
# 3900       Biotecnologias Aplicadas à Patologia Clínica
#
#                      Course_Level(ii)
# 15                 Mestrado 2.º ciclo
# 25                       Licenciatura
# 26             Licenciatura 1.º ciclo
# 27             Licenciatura 1.º ciclo
# 28             Doutoramento 3.º ciclo
# ...                               ...
# 3706               Mestrado 2.º ciclo
# 3897           Doutoramento 3.º ciclo
# 3898           Doutoramento 3.º ciclo
# 3899               Mestrado 2.º ciclo
# 3900  Especialização pós-licenciatura
#
# [76 rows x 4 columns]
